# %%
from weather_wrangler import WeatherWrangler

# Set logging level to info
import logging
logging.basicConfig(level=logging.INFO)

# %%
wdw = WeatherWrangler()

# %%
df = wdw.get_historical_weather_data(56.0021, -3.78535, '2025-01-28', '2025-01-30')

# %%
df
# Out:
#                   time  airTemperature  pressure  windSpeed  windDirection  \
# 0  2025-01-28 00:00:00            4.20    976.16       2.62          22.95
# 1  2025-01-28 01:00:00            4.15    976.64       2.65          26.25
# 2  2025-01-28 02:00:00            4.15    976.80       2.68          29.55
# 3  2025-01-28 03:00:00            4.20    977.77       2.71          32.85
# 4  2025-01-28 04:00:00            4.37    978.34       2.83          29.35
# 5  2025-01-28 05:00:00            4.42    979.28       2.95          25.86
# 6  2025-01-28 06:00:00            4.32    979.73       3.07          22.36
# 7  2025-01-28 07:00:00            4.45    980.81       2.83          16.96
# 8  2025-01-28 08:00:00            4.69    981.84       2.60          11.57
# 9  2025-01-28 09:00:00            5.08    982.88       2.36           6.17
# 10 2025-01-28 10:00:00            5.26    983.45       2.21         349.19
# ...
